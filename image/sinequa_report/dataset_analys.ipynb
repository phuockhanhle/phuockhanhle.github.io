# %% [markdown]
# This notebook is used to analyze on dataset (), in order to explore the different features of each on. I plan to explore on :
#
# *   Élément de liste
# *   Élément de liste
#
# First part of the code would be explore on a specific dataset in order to fine what feature to understand. Based on that, I plan to write a common code that can be applied on every dataset
